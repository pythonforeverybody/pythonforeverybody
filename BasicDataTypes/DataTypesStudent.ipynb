# %%
2+2
# Out:
# 4

# %% [markdown]
# # Practice: List
#
# ```
# falcon1_launch=[ '2006-03-24 22:30', '2007-03-21', '2008-08-03', '2008-09-28 23:15', 2009-07-14']
# ```
# All Launches attempt of Falcon 1:
# ![image.png](data:image/png;base64,...)
# Update List falcon1_launch—so that
# 	- falcon1_launch has only successful launch
# 	- falcon1_launch has both date and time
# 	output looks like: [ ‘2008-09-28 23:15’, ‘2009-07-14 03:35’]
#
# ###Hint
# 1.your_list=[]
# 2. removing: your_list.remove (item), your_list.pop(index),del your_list[start_index, end_index]
# 3.adding item: your_list.insert(index,item), your_list.append(item)
#
# ###*Things to know*
# 1. your_list.sort()
# 2. len(your_list)
# 3. your_list.reverse()
# 4. your_list.clear()
# ### [List Docs](https://docs.python.org/3/tutorial/datastructures.html)

# %% [markdown]
# #Solution 1

# %% [markdown]
# # Problem 2: Dictionary
# ### Distance Kepler used in his experment
# ```
# dis_from_earth={'Mercury': 0.389, 'Venus': 0.724, 'Earth': 1, 'Mars': 1.524, 'Jupiter': 5.20, 'Saturn': 9.510}
# ```
# 1. The distance based on the new instrument is different then, what Kepler used in 1618>
# 2. Update dictionary “planet_distance_sun”
# 3. Add distance of Uranus and Neptun
# 4. Change it to distance in miles [1 AU= 92955807 miles]
#
# ###The actual distance from earth are
# ![image.png](data:image/png;base64,...)
#
#
# ### Hints:
# 1. my_dict={}
# 2. Add item in dictionary: my_dict[key]= value
# 3. Update Item: my_dict.update({key1:new_value1, key2:new_value2})
#
# ###Important dictionary Operations
# 1. Get all Keys: my_dict.keys()
# 2. get all values: my_dict.values()

# %% [markdown]
# # Solution Problem 2

# %% [markdown]
# #Problem 3: String Manupulation
# ```
# national_anthem='''O say can you see, by the dawn’s early light,
# What so proudly we hail’d at the twilight’s last gleaming,
# Whose broad stripes and bright stars through the perilous fight
# O’er the ramparts we watch’d were so gallantly streaming?
# And the rocket’s red glare, the bombs bursting in air,
# Gave proof through the night that our flag was still there,
# O say does that star-spangled banner yet wave
# O’er the land of the free and the home of the brave?'''
# ```
# The national anthem just include first paragraph
# 1. complete national anthem
# 2. Change to lowercase
# 3. Identify first  42 characters, and print that word

# %% [markdown]
# #Solution Problem 3

# %% [markdown]
# #Practice Exercise 4: List Comprehension
# ![Screen Shot 2022-05-14 at 4.42.52 PM.png](data:image/png;base64,...)
#
# ```
# tesla_car=[('Model S', 99990, 405), ('Model Y', 62990, 330), ('Model 3', 46990, 272)
# ```
# * Task 1: Identify the price including tax at NYC
# * Task2: If the range is less then 300 miles, remove the car
# ####Parmeters
# * State Incentive= 2000
# * Tax Rate = 8.875%
# *Retrieved from: https://www.tesla.com/compare at May 12 2022,  *True price may be different. This is just for example purpose. Please check tesla.com for full info*
#
# ```
# tesla_choice=[(model,price+price*tax/100-state_incentive,milage) for (model, price, milage) in tesla_car if milage >=300]
#
# ```
